# %%
# Do not reinvert the wheel

# %%
from faker import Faker

fake = Faker()
fake.name()
# Out:
# 'Daniel Daniels'

# %%
fake.address()
# Out:
# '7599 Villa Trail\nTammyview, ND 32289'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Roy Greene', '3235 Shane Fields\nSouth Jessefort, VA 22179'), ('Kathryn Fernandez', '54815 Patton Springs Apt. 838\nRothside, NM 71336'), ('Jermaine Porter', '1618 Jesse Plains Suite 318\nEast Amyhaven, WA 59995'), ('Kimberly Jackson', '1992 Anthony Parks Apt. 374\nWuview, ID 14110'), ('Paul Smith', '1254 Rachel Falls\nLake Hollyberg, IA 93108'), ('Stephen Graham', '54881 Susan Port Apt. 575\nSouth Troy, FM 22041'), ('Mark Kemp', '838 James Extensions\nRhondahaven, FM 58079'), ('Andrea Johnson', '7489 Kenneth Villages\nNorth Jennifer, NH 91176'), ('Wanda Simon', '66135 Smith Islands Suite 843\nNew Ryan, LA 63894'), ('Tina Cruz', '14441 Laura Inlet Suite 875\nDavisfort, KY 28093'), ('Rebekah Rodriguez', '4773 Owen Dam Suite 351\nGarciaside, AS 95848'), ('John Mcgrath', 'PSC 0841, Box 0979\nAPO AE 94036'), ('Robert Schmidt', '44071 Huff Brooks Suite 196\nPort Erikachester, LA 98247'), ('Samuel Scott', '30367 Scott Plaza\nAlexanderside, HI 17589'), ('Marcus Brady', '049 Reyes Harbors
# ...
