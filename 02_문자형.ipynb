# %%
# 큰따음표
"Life is too short, you need Python"


# 작은따음표 둘러싸기
'Python is fun'

# 큰따움표 3개를 연속으로 둘러싸기
"""Life is too short, 
you need Python"""

#작은 따음표 3개를 연속으로 둘러싸기
'''Life is too short, 
you need Python'''
# Out:
# 'Life is too short, \nyou need Python'

# %%
food = "Python's favorite food is perl"
say =  '"Python is very easy." he says'

# 역슬래시를 사용해서 작은따움표와 큰따움표를 문자열에 포함하기
food = 'Python\'s favorite food is perl'
food

say =  "\"Python is very easy.\" he says"
# Out:
# "Python's favorite food is perl"

# %%
# 줄을 바꾸기 위한 이스캐이프 코드 \n
a = "Life is too short,\n you need Python"
print(a)
# Out:
# Life is too short,
#  you need Python

# %%
a = "Life is too short,\t you need Python"
print(a)
# Out:
# Life is too short,	 you need Python

# %%
# 문자열 더하기 연산

a = "Python"
b = " is fun"

a + b
# Out:
# 'Python is fun'

# %%
# 뮨자열 곱하기 연산

a = "Python"

a * 3
# Out:
# 'PythonPythonPython'

# %%
print("="*30)
print("Python")
print("="*30)
# Out:
# ==============================
# Python
# ==============================

# %%
# 문자열 길이 구하기

a = "Life is too short, You neeed Python"
len(a)
# Out:
# 35

# %%
# 문자열 인덱싱과 슬라이싱

a = "Life is too short, You neeed Python"
a[-1]
# Out:
# 'n'
